# %% [markdown]
# # CS 5542 — Lab 2: Advanced RAG Systems Engineering (Revised Notebook)
# **Chunking → Hybrid Search → Re-ranking → Grounded QA → Evaluation**
#
# **Submission:** Survey
# **Submission Date:** January 29 (Thursday), at the end of class
#
# ## New Requirement (Important)
# For **full credit**, you must add **your own explanations** for key steps:
#
# - After each **IMPORTANT** code cell, write a short **Cell Description** (2–5 sentences) in a Markdown cell:
#   - What the cell does
#   - Why the step matters in a RAG system
#   - Any assumptions/choices you made (e.g., chunk size, α, embedding model)
#
# > Tip: Treat your descriptions like “mini system documentation.” This is how engineers communicate system design.

# %% [markdown]
# ## Project Dataset Guide (Required for Full Credit)
#
# To earn **full credit (2% individual)** you must run this lab on **your own project-aligned dataset**, not only the benchmark.
#
# ### Minimum project dataset requirements
# - **3–20 documents** (start small; you can scale later)
# - Prefer **plain text** documents (`.txt`) for Lab 2
# - Total size: **at least ~3–10 pages** of content across all files
#
# ### Recommended dataset types (choose one)
# - Course / technical docs (manuals, API docs, tutorials)
# - Research papers (your topic area) converted to text
# - Policies / guidelines / compliance docs
# - Meeting notes / project reports
# - Domain corpus (healthcare, cybersecurity, business, etc.)
#
# ### Folder structure (required)
# Create a folder named `project_data/` and put files inside:
# - `project_data/doc1.txt`
# - `project_data/doc2.txt`
# - ...
#
# > If you have PDFs, convert them to text first (instructions below).

# %%
# ✅ IMPORTANT: Create a project_data folder and add your files
import os, glob

PROJECT_FOLDER = "project_data"
os.makedirs(PROJECT_FOLDER, exist_ok=True)

print("✅ Folder ready:", PROJECT_FOLDER)
print("Put 3–20 .txt files into ./project_data/")
print("Currently found:", len(glob.glob(os.path.join(PROJECT_FOLDER, "*.txt"))), "txt files")
# Out:
# ✅ Folder ready: project_data
# Put 3–20 .txt files into ./project_data/
# Currently found: 5 txt files

# %% [markdown]
# ### If you are using Google Colab (Upload files)
#
# **Option A — Upload manually**
# 1. Click the **Files** icon (left sidebar)
# 2. Click **Upload**
# 3. Upload your `.txt` files
# 4. Move them into `project_data/` (or upload directly into that folder)
#
# **Option B — Pull from GitHub**
# If your project docs are in a GitHub repo, you can clone it and copy files into `project_data/`.

# %%
# (Colab only) Optional helper: move uploaded .txt files into project_data/
# Skip if you're not in Colab or you already placed files correctly.

import shutil, glob, os

PROJECT_FOLDER = "project_data"
os.makedirs(PROJECT_FOLDER, exist_ok=True)

moved = 0
for fp in glob.glob("*.txt"):
    shutil.move(fp, os.path.join(PROJECT_FOLDER, os.path.basename(fp)))
    moved += 1

print(f"Moved {moved} files into {PROJECT_FOLDER}/")
print("Now found:", len(glob.glob(os.path.join(PROJECT_FOLDER, '*.txt'))), "txt files")
# Out:
# Moved 0 files into project_data/
# Now found: 5 txt files

# %% [markdown]
# ### If your sources are PDFs (Optional)
#
# For Lab 2, we recommend converting PDFs to `.txt` first.
#
# **Simple approach (good enough for class):**
# - Copy/paste text from the PDF into a `.txt` file.
#
# **Programmatic approach (optional):**
# If your PDF is text-based (not scanned), you can extract text using `pypdf`.

# %%
# OPTIONAL: PDF → TXT conversion (only for text-based PDFs)
# If your PDFs are scanned images, this won't work well without OCR.

# !pip -q install pypdf

from pathlib import Path
import os

def pdf_to_txt(pdf_path: str, out_folder: str = "project_data"):
    from pypdf import PdfReader
    reader = PdfReader(pdf_path)
    text = []
    for page in reader.pages:
        text.append(page.extract_text() or "")
    txt = "\n\n".join(text).strip()

    os.makedirs(out_folder, exist_ok=True)
    out_path = Path(out_folder) / (Path(pdf_path).stem + ".txt")
    out_path.write_text(txt, encoding="utf-8", errors="ignore")
    return str(out_path), len(txt)

# Example usage:
# out_path, n_chars = pdf_to_txt("/content/your_file.pdf")
# print("Saved:", out_path, "| chars:", n_chars)

# %% [markdown]
# ### Project Queries + Mini Rubric (Required)
#
# You must define **3 project queries**:
# - Q1, Q2: normal (typical user questions)
# - Q3: ambiguous / tricky (edge case)
#
# Also define a **mini rubric** for each query:
# - What counts as “relevant evidence”? (keywords, entities, definitions, constraints)
# - What would a correct answer look like? (1–2 bullet points)
#
# This rubric makes your evaluation meaningful (Precision@K / Recall@K).

# %%
# ✅ REQUIRED: Define your project queries and mini rubric
project_queries = {
    "Q1": {
        "query": "What are the main types of hallucination in RAG systems and what causes them?",
        "rubric_relevant_evidence": [
            "Definitions of intrinsic hallucination (contradicts source)",
            "Definitions of extrinsic hallucination (info not in sources)",
            "Retrieval-induced hallucination (poor retrieval quality)",
            "Root causes: training data noise, attention limitations, probability maximization",
        ],
        "rubric_correct_answer": [
            "Should list at least 3 types of hallucination with brief definitions",
            "Should mention at least 2 root causes explaining why hallucination occurs",
        ],
    },
    "Q2": {
        "query": "When should I choose RAG over fine-tuning for my LLM application?",
        "rubric_relevant_evidence": [
            "RAG preferred for: frequently changing info, large knowledge bases, source attribution",
            "Fine-tuning preferred for: domain language, behavioral modification, latency-critical apps",
            "Cost and scalability tradeoffs between approaches",
            "Hybrid approach combining both methods",
        ],
        "rubric_correct_answer": [
            "Should describe at least 2-3 scenarios where RAG is preferred with reasoning",
            "Should contrast with scenarios where fine-tuning is better",
        ],
    },
    "Q3_ambiguous": {
        "query": "How do I improve my RAG system?",
        "rubric_relevant_evidence": [
            "Could relate to: retrieval quality, hallucination mitigation, latency, cost",
            "Advanced architectures: hybrid search, re-ranking, hierarchical retrieval",
            "Production considerations: caching, monitoring, scaling",
            "Chunking strategies and their impact on quality",
        ],
        "rubric_correct_answer": [
            "Answer depends on interpretation - could focus on accuracy, speed, or cost",
            "Good answer should acknowledge ambiguity or ask for clarification, OR cover multiple improvement dimensions",
        ],
    },
}

project_queries
# Out:
# {'Q1': {'query': 'What are the main types of hallucination in RAG systems and what causes them?',
#   'rubric_relevant_evidence': ['Definitions of intrinsic hallucination (contradicts source)',
#    'Definitions of extrinsic hallucination (info not in sources)',
#    'Retrieval-induced hallucination (poor retrieval quality)',
#    'Root causes: training data noise, attention limitations, probability maximization'],
#   'rubric_correct_answer': ['Should list at least 3 types of hallucination with brief definitions',
#    'Should mention at least 2 root causes explaining why hallucination occurs']},
#  'Q2': {'query': 'When should I choose RAG over fine-tuning for my LLM application?',
#   'rubric_relevant_evidence': ['RAG preferred for: frequently changing info, large knowledge bases, source attribution',
#    'Fine-tuning preferred for: domain language, behavioral modification, latency-critical apps',
#    'Cost and scalability tradeoffs between approaches',
#    'Hybrid approach combining both methods'],
#   'rubric_correct_answer': ['Should describe at least 2-3 scenarios where RAG is preferred with reasoning',
#    'Should contrast with scenarios where fine-tuning is better']},
#  'Q3_ambiguous': {'query': 'How do I improve my RAG system?',
#   'rubric_relevant_evidence': ['Could relate to: retrieval quality, hallucination mitigation, latency, cost',
#    'Advanced architectures: hybrid search, re-ranking, hierarchical retrieval',
#    'Production considerations: caching, monitoring, scaling',
#    'Chunking strategies and their impact on quality'],
#   'rubric_correct_answer': ['Answer depends on interpretation - could focus on accuracy, speed, or cost',
#    'Good answer should acknowledge ambiguity or ask for clarification, OR cover multiple improvement dimensions']}}

# %% [markdown]
# ### ✍️ Cell Description (Student)
# Explain what files you used for your project dataset, why they match your scenario, and how you designed your 3 queries + rubric.
#
# So I decided to use RAG because I thought it would help me with learning this topic. I asked claude opus to generate the files with the context that it would be for a RAG system. Then I prompted it to fill out the above section and exaplin to me why it chose the qustions and rubric it chose. Below it was it said:
#
#
# ## Q1: "What are the main types of hallucination in RAG systems and what causes them?"
# Why I chose this:
# - Clear and factual - Has a definitive answer in hallucination_mitigation.txt
# - Tests retrieval precision - The system needs to find the specific section defining hallucination types (intrinsic, extrinsic, retrieval-induced, compositional)
# - Domain-relevant - Hallucination is a core RAG challenge that wasn't covered in your lab's implementation sections
# Rubric rationale: The evidence requirements map directly to specific passages in the document. A correct answer should enumerate types and causes, making it easy to evaluate.
# ## Q2: "When should I choose RAG over fine-tuning for my LLM application?"
# Why I chose this:
# - Requires synthesis - The answer spans multiple sections of rag_vs_finetuning.txt
# - Decision-oriented - Tests whether the system can retrieve comparative/tradeoff information
# - Practical relevance - A question real practitioners ask when building LLM apps
# Rubric rationale: Good evidence includes both "when to choose RAG" and "when to choose fine-tuning" passages. A correct answer needs to contrast both approaches, not just describe one.
# ## Q3 (Ambiguous): "How do I improve my RAG system?"
# Why I chose this:
# - Intentionally vague - "Improve" could mean:
#     - Better accuracy (hallucination mitigation, re-ranking)
#     - Faster responses (caching, latency optimization)
#     - Lower cost (cost optimization strategies)
#     - Better scalability (production deployment patterns)
# - Tests edge case handling - Multiple documents could be relevant (hallucination_mitigation.txt, rag_architectures_patterns.txt, production_rag_deployment.txt)
# - Real user behavior - Users often ask vague questions; this tests how the system handles ambiguity
# Rubric rationale: There's no single "correct" answer. The rubric acknowledges that a good response should either clarify the ambiguity or address multiple improvement dimensions.

# %% [markdown]
# ## 0) One-Click Setup + Import Check  ✅ **IMPORTANT: Add Cell Description after running**

# %%
# CS 5542 Lab 2 — One-Click Dependency Install
# If your imports fail after installing, restart the runtime/kernel and rerun this cell.

# !pip install -q sentence-transformers faiss-cpu chromadb datasets transformers scikit-learn rank-bm25

import os, glob, re
import numpy as np
import pandas as pd
from typing import List, Tuple, Dict, Set

from datasets import load_dataset
from sklearn.feature_extraction.text import TfidfVectorizer
from rank_bm25 import BM25Okapi

from sentence_transformers import SentenceTransformer
import faiss

from transformers import pipeline

print("✅ Setup complete. If you see dependency warnings, ignore unless imports fail.")
# Out:
# zsh:1: command not found: pip
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 7
#       4 get_ipython().system('pip install -q sentence-transformers faiss-cpu chromadb datasets transformers scikit-learn rank-bm25')
#       6 import os, glob, re
# ----> 7 import numpy as np
#       8 import pandas as pd
#       9 from typing import List, Tuple, Dict, Set
#
# ModuleNotFoundError: No module named 'numpy'

# %% [markdown]
# ### ✍️ Cell Description (Student)
# Write 2–5 sentences explaining what the setup cell does and why restarting the kernel sometimes matters after pip installs.

# %% [markdown]
# ## 1) Load Data (Benchmark + Project Data)  ✅ **IMPORTANT: Add Cell Description after running**

# %%
# Clone your GitHub repo and copy project data files
# !git clone https://github.com/EXC3ll3NTrhyTHM/BigDataAnalytics.git

# Create project_data folder and copy the txt files
import shutil, os
os.makedirs("project_data", exist_ok=True)
# !cp BigDataAnalytics/Week_2/project_data/*.txt project_data/

# Verify files are there
import glob
print("Files in project_data/:", glob.glob("project_data/*.txt"))
# Out:
# Cloning into 'BigDataAnalytics'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 35 (delta 12), reused 29 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (35/35), 58.99 KiB | 974.00 KiB/s, done.
# Resolving deltas: 100% (12/12), done.
# Files in project_data/: ['project_data/production_rag_deployment.txt', 'project_data/rag_vs_finetuning.txt', 'project_data/rag_history_and_evolution.txt', 'project_data/rag_architectures_patterns.txt', 'project_data/hallucination_mitigation.txt']

# %%
# Benchmark Loader (classroom-safe fallback; avoids script-based datasets)
def load_benchmark(n: int = 120) -> List[str]:
    # 1) Try a script-free SciFact source
    try:
        print("Trying allenai/scifact...")
        ds = load_dataset("allenai/scifact", split=f"train[:{n}]")
        sample = ds[0]
        if "claim" in sample:
            return [x["claim"] for x in ds]
        if "text" in sample:
            return [x["text"] for x in ds]
        raise RuntimeError("Unknown SciFact schema.")
    except Exception as e:
        print("⚠️ allenai/scifact failed:", str(e))

    # 2) Try multi_news
    try:
        print("Trying multi_news...")
        ds = load_dataset("multi_news", split=f"train[:{n}]")
        return [x["document"] for x in ds]
    except Exception as e:
        print("⚠️ multi_news failed:", str(e))

    # 3) Fallback: ag_news (very stable)
    print("Using ag_news fallback...")
    ds = load_dataset("ag_news", split=f"train[:{n}]")
    return [x["text"] for x in ds]

# Load benchmark docs
benchmark_docs = load_benchmark(n=120)
print(f"Loaded benchmark docs: {len(benchmark_docs)}")

# Change to the notebook's directory
os.chdir(os.path.dirname(os.path.abspath("CS5542_Lab2_Advanced_RAG.ipynb")) or ".")
print("Working directory:", os.getcwd())

# Load project-aligned docs from ./project_data/*.txt
PROJECT_FOLDER = "project_data"
project_files = sorted(glob.glob(os.path.join(PROJECT_FOLDER, "*.txt")))
project_docs = []
for fp in project_files:
    with open(fp, "r", encoding="utf-8", errors="ignore") as f:
        project_docs.append(f.read())

print(f"Loaded project docs: {len(project_docs)}")
if len(project_docs) == 0:
    print("⚠️ Add 3–20 .txt files under ./project_data/ to earn full credit.")
# Out:
# Trying allenai/scifact...
# ⚠️ allenai/scifact failed: Dataset scripts are no longer supported, but found scifact.py
# Trying multi_news...
# ⚠️ multi_news failed: Dataset scripts are no longer supported, but found multi_news.py
# Using ag_news fallback...
# Loaded benchmark docs: 120
# Working directory: /content
# Loaded project docs: 5

# %% [markdown]
# ### ✍️ Cell Description (Student)
# Explain what dataset(s) you loaded and why we require **project-aligned** data for full credit.
# I loaded the dataset that I created and we need project aligned data so that the data is separate from the training set and allows us to store data and build a RAG system.

# %% [markdown]
# ## 2) Chunking (Fixed vs Semantic)  ✅ **IMPORTANT: Add Cell Description after running**

# %%
# --- Chunking functions ---
def fixed_chunks(text: str, size: int = 1200, overlap: int = 200) -> List[str]:
    """Character-based fixed window chunking (fast and reliable in class)."""
    text = text.strip()
    if not text:
        return []
    chunks = []
    step = max(1, size - overlap)
    for i in range(0, len(text), step):
        c = text[i:i+size].strip()
        if len(c) > 50:
            chunks.append(c)
    return chunks

def semantic_chunks(text: str) -> List[str]:
    """Paragraph-based semantic chunking; merges short segments to keep context."""
    paras = [p.strip() for p in re.split(r"\n\s*\n+", text) if p.strip()]
    merged, buf = [], ""
    for p in paras:
        if len(buf) < 400:
            buf = (buf + "\n\n" + p).strip()
        else:
            merged.append(buf); buf = p
    if buf:
        merged.append(buf)
    return [m for m in merged if len(m) > 80]

def build_corpus(docs: List[str], mode: str) -> List[str]:
    all_chunks = []
    for d in docs:
        if mode == "fixed":
            all_chunks.extend(fixed_chunks(d))
        elif mode == "semantic":
            all_chunks.extend(semantic_chunks(d))
        else:
            raise ValueError("mode must be 'fixed' or 'semantic'")
    return all_chunks

# Build both corpora and choose one to use in retrieval
all_docs = benchmark_docs + project_docs
fixed_corpus = build_corpus(all_docs, mode="fixed")
semantic_corpus = build_corpus(all_docs, mode="semantic")

print("Fixed corpus chunks:", len(fixed_corpus))
print("Semantic corpus chunks:", len(semantic_corpus))

# Choose the corpus for the lab (recommend semantic for better context)
CORPUS = semantic_corpus
print("✅ Using CORPUS =", "semantic" if CORPUS is semantic_corpus else "fixed")
# Out:
# Fixed corpus chunks: 168
# Semantic corpus chunks: 209
# ✅ Using CORPUS = semantic

# %% [markdown]
# ### ✍️ Cell Description (Student)
# Explain the difference between **fixed** and **semantic** chunking and why chunking affects retrieval quality.
#
# Fixed chunking has a predetermined amount of characters to each chunk while semantic chunking uses the semantic embeddings to determine how large or small to make a chunk.

# %% [markdown]
# ## 3) Build Retrieval Indexes (Keyword + Vector)  ✅ **IMPORTANT: Add Cell Description after running**

# %%
# --- Keyword Retrieval (TF-IDF + BM25) ---
def tokenize(s: str) -> List[str]:
    return re.findall(r"[A-Za-z0-9]+", s.lower())

tfidf = TfidfVectorizer(stop_words="english", max_features=50000)
tfidf_matrix = tfidf.fit_transform(CORPUS)

def keyword_tfidf(query: str, k: int = 10) -> List[Tuple[int, float]]:
    q_vec = tfidf.transform([query])
    scores = (tfidf_matrix @ q_vec.T).toarray().squeeze()
    top = np.argsort(scores)[-k:][::-1]
    return [(int(i), float(scores[i])) for i in top]

bm25 = BM25Okapi([tokenize(x) for x in CORPUS])

def keyword_bm25(query: str, k: int = 10) -> List[Tuple[int, float]]:
    scores = bm25.get_scores(tokenize(query))
    top = np.argsort(scores)[-k:][::-1]
    return [(int(i), float(scores[i])) for i in top]

# --- Vector Retrieval (SentenceTransformer + FAISS) ---
embed_model_name = "sentence-transformers/all-MiniLM-L6-v2"
embedder = SentenceTransformer(embed_model_name)

embeddings = embedder.encode(CORPUS, show_progress_bar=True, convert_to_numpy=True, normalize_embeddings=True)
dim = embeddings.shape[1]
faiss_index = faiss.IndexFlatIP(dim)  # cosine via normalized vectors + inner product
faiss_index.add(embeddings)

def vector_search(query: str, k: int = 10) -> List[Tuple[int, float]]:
    q = embedder.encode([query], convert_to_numpy=True, normalize_embeddings=True)
    scores, idx = faiss_index.search(q, k)
    return [(int(i), float(s)) for i, s in zip(idx[0], scores[0])]

print("✅ Retrieval engines ready: TF-IDF, BM25, Vector(FAISS)")
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
# ✅ Retrieval engines ready: TF-IDF, BM25, Vector(FAISS)

# %% [markdown]
# ### ✍️ Cell Description (Student)
# Explain why we build **both** keyword and vector retrieval engines, and when each one is expected to work best.
#
# Keyword search is more simple and retrieves all instances of a keyword or keywords from the dataset while vector retrieval allows us retrieve semantically similar chunks that may not have any keywords in them.

# %% [markdown]
# ## 4) Hybrid Retrieval (α-Weighted Fusion)  ✅ **IMPORTANT: Add Cell Description after running**

# %%
def normalize_scores(pairs: List[Tuple[int, float]]) -> Dict[int, float]:
    if not pairs:
        return {}
    vals = np.array([s for _, s in pairs], dtype=float)
    vmin, vmax = vals.min(), vals.max()
    if vmax - vmin < 1e-9:
        return {i: 1.0 for i, _ in pairs}
    return {i: (s - vmin) / (vmax - vmin) for i, s in pairs}

def hybrid_search(query: str, k_keyword: int = 10, k_vector: int = 10, alpha: float = 0.5,
                  top_k: int = 10, keyword_mode: str = "bm25") -> List[Tuple[int, float]]:
    kw = keyword_bm25(query, k=k_keyword) if keyword_mode == "bm25" else keyword_tfidf(query, k=k_keyword)
    vec = vector_search(query, k=k_vector)

    kw_n = normalize_scores(kw)
    vec_n = normalize_scores(vec)

    all_ids = set(kw_n) | set(vec_n)
    combined = []
    for i in all_ids:
        score = alpha * kw_n.get(i, 0.0) + (1 - alpha) * vec_n.get(i, 0.0)
        combined.append((i, float(score)))

    combined.sort(key=lambda x: x[1], reverse=True)
    return combined[:top_k]

print("✅ Hybrid retrieval ready. You'll sweep alpha ∈ {0.2, 0.5, 0.8}.")
# Out:
# ✅ Hybrid retrieval ready. You'll sweep alpha ∈ {0.2, 0.5, 0.8}.

# %% [markdown]
# ### ✍️ Cell Description (Student)
# Explain what **hybrid fusion** is and what the α parameter means (semantic-heavy vs keyword-heavy).
#
# Hybrid fusion returns both chunks using keyword search and semantic search. alpha parameter shows whether a chunk was retrieved by keyword or sematnic search. I think it has to do with how semantically close to the question a chunk is.

# %% [markdown]
# ## 5) Re-ranking (Cross-Encoder if available)  ✅ **IMPORTANT: Add Cell Description after running**

# %%
USE_CROSS_ENCODER = True
reranker = None

if USE_CROSS_ENCODER:
    try:
        from sentence_transformers import CrossEncoder
        reranker = CrossEncoder("cross-encoder/ms-marco-MiniLM-L-6-v2")
        print("✅ Cross-encoder reranker loaded.")
    except Exception as e:
        print("⚠️ Cross-encoder not available. Falling back to no reranking.")
        print("Error:", e)
        reranker = None

def rerank(query: str, candidates: List[Tuple[int, float]], top_k: int = 5) -> List[Tuple[int, float]]:
    ids = [i for i, _ in candidates]
    if reranker is None:
        return candidates[:top_k]
    pairs = [(query, CORPUS[i]) for i in ids]
    scores = reranker.predict(pairs)
    scored = list(zip(ids, scores))
    scored.sort(key=lambda x: x[1], reverse=True)
    return [(int(i), float(s)) for i, s in scored[:top_k]]

print("✅ Reranking function ready.")
# Out:
# config.json:   0%|          | 0.00/794 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# ✅ Cross-encoder reranker loaded.
# ✅ Reranking function ready.

# %% [markdown]
# ### ✍️ Cell Description (Student)
# Explain what reranking does and why it often improves Precision@K (but costs extra compute).
#
# Reranking will take the results and rerank them based on their semantic distance from the question. It is a light action because it deals with only a few amount of chunks. It improves the top k because a close but wrong answer can be reranked to below and more relevant answer.

# %% [markdown]
# ## 6) Run Your 3 Project Queries + Generate Answers  ✅ **IMPORTANT: Add Cell Description after running**

# %%
# Generator (small + class-friendly)
gen = pipeline("text2text-generation", model="google/flan-t5-base")

def prompt_only_answer(query: str, max_new_tokens: int = 200) -> str:
    return gen(query, max_new_tokens=max_new_tokens)[0]["generated_text"]

def rag_answer(query: str, chunk_ids: List[int], max_new_tokens: int = 220) -> str:
    evidence = "\n\n".join([f"[Chunk {j+1}] {CORPUS[i]}" for j, i in enumerate(chunk_ids)])
    prompt = f"""Answer the question using ONLY the evidence below.

Evidence:
{evidence}

Question:
{query}

Rules:
- If evidence is insufficient, say: Not enough evidence.
- Cite evidence with [Chunk 1], [Chunk 2], etc.
"""
    return gen(prompt, max_new_tokens=max_new_tokens)[0]["generated_text"]

def show_top(pairs: List[Tuple[int, float]], title: str, k: int = 5):
    print(f"\n=== {title} (Top {k}) ===")
    for r, (i, s) in enumerate(pairs[:k], 1):
        snip = CORPUS[i].replace("\n", " ")
        snip = snip[:220] + ("..." if len(snip) > 220 else "")
        print(f"{r:>2}. id={i:<6} score={s:>8.4f} | {snip}")

# ✅ REQUIRED: Replace with your project queries
queries = [
    "Q1: " + project_queries["Q1"]["query"],
    "Q2: " + project_queries["Q2"]["query"],
    "Q3 (ambiguous): " + project_queries["Q3_ambiguous"]["query"],
]

alphas = [0.2, 0.5, 0.8]
results_summary = []

for q in queries:
    print("\n" + "="*90)
    print(q)

    kw = keyword_bm25(q, k=10)
    vec = vector_search(q, k=10)
    show_top(kw, "BM25 Keyword")
    show_top(vec, "Vector (FAISS)")

    hybrids = []
    for a in alphas:
        hyb = hybrid_search(q, alpha=a, top_k=10, keyword_mode="bm25")
        hybrids.append((a, hyb))
        show_top(hyb, f"Hybrid (alpha={a})")

    best_a, _ = max(hybrids, key=lambda t: np.mean([s for _, s in t[1]]) if t[1] else -1)
    print(f"\nSelected hybrid alpha={best_a}")

    candidate_pool = hybrid_search(q, alpha=best_a, top_k=20, keyword_mode="bm25")
    reranked = rerank(q, candidate_pool, top_k=5)
    show_top(reranked, "Re-ranked")

    top3_ids = [i for i, _ in reranked[:3]]
    print("\nTop-3 evidence chunk IDs:", top3_ids)

    po = prompt_only_answer(q)
    ra = rag_answer(q, top3_ids)

    print("\n--- Prompt-only answer ---\n", po)
    print("\n--- RAG-grounded answer ---\n", ra)

    results_summary.append({
        "query": q,
        "best_alpha": best_a,
        "top3_chunk_ids": top3_ids,
        "prompt_only": po,
        "rag": ra,
    })

results_summary[:1]
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# Device set to use cpu
# ==========================================================================================
# Q1: What are the main types of hallucination in RAG systems and what causes them?
#
# === BM25 Keyword (Top 5) ===
#  1. id=163    score= 21.1209 | Advanced RAG addresses these limitations through multiple enhancements:  Pre-retrieval Optimization: Query rewriting expands or reformulates the user's question to improve retrieval. For example, "What causes global warm...
#  2. id=121    score= 17.5042 | Types of Hallucination in RAG Systems  Intrinsic Hallucination occurs when the generated output contradicts the provided source documents. The model might state the opposite of what the evidence says or confuse details b...
#  3. id=175    score= 14.8865 | Conversation-Aware RAG  Chatbot applications require RAG systems that maintain conversation context:  Query Contextualization: The current query is rewritten to include relevant context from conversation history. "What a...
#  4. id=120    score= 14.2932 | Hallucination Mitigation Strategies in RAG Systems  Understanding Hallucination in Language Models  Hallucination refers to the phenomenon where language models generate content that is factually incorrect, nonsensical, ...
#  5. id=53     score= 12.2790 | What's Cool In the Pool ... ... And Hot On the Deck Americans are spending more on tricking out the places where they swim. Here's a look at the new wave of accessories
#
# === Vector (FAISS) (Top 5) ===
#  1. id=121    score=  0.6485 | Types of Hallucination in RAG Systems  Intrinsic Hallucination occurs when the generated output contradicts the provided source documents. The model might state the opposite of what the evidence says or confuse details b...
#  2. id=120    score=  0.5600 | Hallucination Mitigation Strategies in RAG Systems  Understanding Hallucination in Language Models  Hallucination refers to the phenomenon where language models generate content that is factually incorrect, nonsensical, ...
#  3. id=122    score=  0.3909 | Retrieval-Induced Hallucination emerges from poor retrieval quality. If retrieved documents are irrelevant or only tangentially related to the query, the model may hallucinate to produce a seemingly responsive answer.  C...
#  4. id=123    score=  0.3737 | Root Causes of Hallucination  Understanding why hallucination occurs helps in designing effective mitigation strategies:  Training Data Noise: LLMs are trained on internet text containing errors, outdated information, an...
#  5. id=137    score=  0.3647 | Emerging Research Directions  Active research areas in hallucination mitigation include:  Retrieval-Augmented Generation with Verification (RAVE): End-to-end systems that jointly optimize retrieval, generation, and verif...
#
# === Hybrid (alpha=0.2) (Top 5) ===
#  1. id=121    score=  0.9376 | Types of Hallucination in RAG Systems  Intrinsic Hallucination occurs when the generated output contradicts the provided source documents. The model might state the opposite of what the evidence says or confuse details b...
#  2. id=120    score=  0.6725 | Hallucination Mitigation Strategies in RAG Systems  Understanding Hallucination in Language Models  Hallucination refers to the phenomenon where language models generate content that is factually incorrect, nonsensical, ...
#  3. id=163    score=  0.2000 | Advanced RAG addresses these limitations through multiple enhancements:  Pre-retrieval Optimization: Query rewriting expands or reformulates the user's question to improve retrieval. For example, "What causes global warm...
#  4. id=122    score=  0.1898 | Retrieval-Induced Hallucination emerges from poor retrieval quality. If retrieved documents are irrelevant or only tangentially related to the query, the model may hallucinate to produce a seemingly responsive answer.  C...
#  5. id=123    score=  0.1593 | Root Causes of Hallucination  Understanding why hallucination occurs helps in designing effective mitigation strategies:  Training Data Noise: LLMs are trained on internet text containing errors, outdated information, an...
#
# === Hybrid (alpha=0.5) (Top 5) ===
#  1. id=121    score=  0.8439 | Types of Hallucination in RAG Systems  Intrinsic Hallucination occurs when the generated output contradicts the provided source documents. The model might state the opposite of what the evidence says or confuse details b...
#  2. id=120    score=  0.5744 | Hallucination Mitigation Strategies in RAG Systems  Understanding Hallucination in Language Models  Hallucination refers to the phenomenon where language models generate content that is factually incorrect, nonsensical, ...
#  3. id=163    score=  0.5000 | Advanced RAG addresses these limitations through multiple enhancements:  Pre-retrieval Optimization: Query rewriting expands or reformulates the user's question to improve retrieval. For example, "What causes global warm...
#  4. id=175    score=  0.2310 | Conversation-Aware RAG  Chatbot applications require RAG systems that maintain conversation context:  Query Contextualization: The current query is rewritten to include relevant context from conversation history. "What a...
#  5. id=123    score=  0.1188 | Root Causes of Hallucination  Understanding why hallucination occurs helps in designing effective mitigation strategies:  Training Data Noise: LLMs are trained on internet text containing errors, outdated information, an...
#
# === Hybrid (alpha=0.8) (Top 5) ===
#  1. id=163    score=  0.8000 | Advanced RAG addresses these limitations through multiple enhancements:  Pre-retrieval Optimization: Query rewriting expands or reformulates the user's question to improve retrieval. For example, "What causes global warm...
#  2. id=121    score=  0.7503 | Types of Hallucination in RAG Systems  Intrinsic Hallucination occurs when the generated output contradicts the provided source documents. The model might state the opposite of what the evidence says or confuse details b...
#  3. id=120    score=  0.4762 | Hallucination Mitigation Strategies in RAG Systems  Understanding Hallucination in Language Models  Hallucination refers to the phenomenon where language models generate content that is factually incorrect, nonsensical, ...
#  4. id=175    score=  0.3696 | Conversation-Aware RAG  Chatbot applications require RAG systems that maintain conversation context:  Query Contextualization: The current query is rewritten to include relevant context from conversation history. "What a...
#  5. id=53     score=  0.1896 | What's Cool In the Pool ... ... And Hot On the Deck Americans are spending more on tricking out the places where they swim. Here's a look at the new wave of accessories
#
# Selected hybrid alpha=0.8
#
# === Re-ranked (Top 5) ===
#  1. id=121    score=  5.2866 | Types of Hallucination in RAG Systems  Intrinsic Hallucination occurs when the generated output contradicts the provided source documents. The model might state the opposite of what the evidence says or confuse details b...
#  2. id=120    score=  3.2020 | Hallucination Mitigation Strategies in RAG Systems  Understanding Hallucination in Language Models  Hallucination refers to the phenomenon where language models generate content that is factually incorrect, nonsensical, ...
#  3. id=138    score=  0.6662 | Multi-Modal Verification: Using images, tables, and structured data to verify or refute generated text claims.  Conclusion  Hallucination remains one of the most significant challenges in deploying RAG systems, particula...
#  4. id=198    score= -0.4939 | Accuracy and Hallucination  RAG Characteristics: RAG grounds responses in retrieved evidence, which can reduce hallucination when retrieval is successful. However, if retrieval fails (query-document mismatch, relevant in...
#  5. id=171    score= -2.8401 | These self-reflection steps can be implemented through special tokens or separate critic models. Self-RAG improves factual accuracy and reduces hallucination by making retrieval and grounding explicit.  Corrective RAG (C...
#
# Top-3 evidence chunk IDs: [121, 120, 138]
#
# --- Prompt-only answer ---
#  drowsiness and hallucinations
#
# --- RAG-grounded answer ---
#  Cite evidence with [Chunk 1], [Chunk 2], etc.
#
# ==========================================================================================
# Q2: When should I choose RAG over fine-tuning for my LLM application?
#
# === BM25 Keyword (Top 5) ===
#  1. id=189    score= 17.4846 | RAG vs Fine-Tuning: Choosing the Right Approach for Your LLM Application  Introduction to Knowledge Enhancement Methods  When building AI applications that require domain-specific knowledge, developers face a fundamental...
#  2. id=194    score= 13.7600 | When to Choose Fine-Tuning  Fine-tuning is more appropriate when:  Learning Domain Language: If your domain uses specialized terminology, jargon, or writing styles, fine-tuning helps the model understand and generate app...
#  3. id=191    score= 12.3834 | Hybrid Approaches combine both: fine-tuning improves the model's understanding of domain terminology and reasoning patterns while RAG provides access to detailed, up-to-date factual information.  When to Choose RAG  RAG ...
#  4. id=207    score= 12.2638 | Decision Framework Summary  Choose RAG when: - Knowledge changes frequently - Source attribution is required - Knowledge base is large or growing - Budget for training is limited - Multiple knowledge bases needed  Choose...
#  5. id=205    score= 10.9385 | Team Skills: RAG development aligns with traditional software engineering (databases, APIs, systems). Fine-tuning requires ML engineering expertise (training pipelines, GPU optimization, evaluation).  Case Studies and Re...
#
# === Vector (FAISS) (Top 5) ===
#  1. id=208    score=  0.6776 | Conclusion  The RAG vs fine-tuning decision is not binary. Understanding the strengths and limitations of each approach enables practitioners to design systems that leverage both as appropriate. As the field evolves, we ...
#  2. id=191    score=  0.6604 | Hybrid Approaches combine both: fine-tuning improves the model's understanding of domain terminology and reasoning patterns while RAG provides access to detailed, up-to-date factual information.  When to Choose RAG  RAG ...
#  3. id=196    score=  0.5730 | Task-Specific Optimization: For narrow tasks (classification, extraction, specific QA formats), fine-tuning can achieve superior performance compared to prompting general models.  Knowledge Freshness and Updates  RAG Adv...
#  4. id=189    score=  0.5688 | RAG vs Fine-Tuning: Choosing the Right Approach for Your LLM Application  Introduction to Knowledge Enhancement Methods  When building AI applications that require domain-specific knowledge, developers face a fundamental...
#  5. id=203    score=  0.5396 | RAG-Aware Fine-Tuning: Fine-tune the model specifically for RAG scenarios, training it to effectively use retrieved context and know when retrieval is insufficient.  Routing Between Approaches: Use a classifier to route ...
#
# === Hybrid (alpha=0.2) (Top 5) ===
#  1. id=191    score=  0.8307 | Hybrid Approaches combine both: fine-tuning improves the model's understanding of domain terminology and reasoning patterns while RAG provides access to detailed, up-to-date factual information.  When to Choose RAG  RAG ...
#  2. id=208    score=  0.8000 | Conclusion  The RAG vs fine-tuning decision is not binary. Understanding the strengths and limitations of each approach enables practitioners to design systems that leverage both as appropriate. As the field evolves, we ...
#  3. id=189    score=  0.6198 | RAG vs Fine-Tuning: Choosing the Right Approach for Your LLM Application  Introduction to Knowledge Enhancement Methods  When building AI applications that require domain-specific knowledge, developers face a fundamental...
#  4. id=196    score=  0.4346 | Task-Specific Optimization: For narrow tasks (classification, extraction, specific QA formats), fine-tuning can achieve superior performance compared to prompting general models.  Knowledge Freshness and Updates  RAG Adv...
#  5. id=203    score=  0.3234 | RAG-Aware Fine-Tuning: Fine-tune the model specifically for RAG scenarios, training it to effectively use retrieved context and know when retrieval is insufficient.  Routing Between Approaches: Use a classifier to route ...
#
# === Hybrid (alpha=0.5) (Top 5) ===
#  1. id=189    score=  0.7624 | RAG vs Fine-Tuning: Choosing the Right Approach for Your LLM Application  Introduction to Knowledge Enhancement Methods  When building AI applications that require domain-specific knowledge, developers face a fundamental...
#  2. id=191    score=  0.6890 | Hybrid Approaches combine both: fine-tuning improves the model's understanding of domain terminology and reasoning patterns while RAG provides access to detailed, up-to-date factual information.  When to Choose RAG  RAG ...
#  3. id=208    score=  0.5000 | Conclusion  The RAG vs fine-tuning decision is not binary. Understanding the strengths and limitations of each approach enables practitioners to design systems that leverage both as appropriate. As the field evolves, we ...
#  4. id=194    score=  0.3003 | When to Choose Fine-Tuning  Fine-tuning is more appropriate when:  Learning Domain Language: If your domain uses specialized terminology, jargon, or writing styles, fine-tuning helps the model understand and generate app...
#  5. id=196    score=  0.2716 | Task-Specific Optimization: For narrow tasks (classification, extraction, specific QA formats), fine-tuning can achieve superior performance compared to prompting general models.  Knowledge Freshness and Updates  RAG Adv...
#
# === Hybrid (alpha=0.8) (Top 5) ===
#  1. id=189    score=  0.9050 | RAG vs Fine-Tuning: Choosing the Right Approach for Your LLM Application  Introduction to Knowledge Enhancement Methods  When building AI applications that require domain-specific knowledge, developers face a fundamental...
#  2. id=191    score=  0.5474 | Hybrid Approaches combine both: fine-tuning improves the model's understanding of domain terminology and reasoning patterns while RAG provides access to detailed, up-to-date factual information.  When to Choose RAG  RAG ...
#  3. id=194    score=  0.4804 | When to Choose Fine-Tuning  Fine-tuning is more appropriate when:  Learning Domain Language: If your domain uses specialized terminology, jargon, or writing styles, fine-tuning helps the model understand and generate app...
#  4. id=207    score=  0.3521 | Decision Framework Summary  Choose RAG when: - Knowledge changes frequently - Source attribution is required - Knowledge base is large or growing - Budget for training is limited - Multiple knowledge bases needed  Choose...
#  5. id=205    score=  0.2384 | Team Skills: RAG development aligns with traditional software engineering (databases, APIs, systems). Fine-tuning requires ML engineering expertise (training pipelines, GPU optimization, evaluation).  Case Studies and Re...
#
# Selected hybrid alpha=0.2
#
# === Re-ranked (Top 5) ===
#  1. id=189    score=  5.1290 | RAG vs Fine-Tuning: Choosing the Right Approach for Your LLM Application  Introduction to Knowledge Enhancement Methods  When building AI applications that require domain-specific knowledge, developers face a fundamental...
#  2. id=191    score=  3.6777 | Hybrid Approaches combine both: fine-tuning improves the model's understanding of domain terminology and reasoning patterns while RAG provides access to detailed, up-to-date factual information.  When to Choose RAG  RAG ...
#  3. id=207    score=  3.2397 | Decision Framework Summary  Choose RAG when: - Knowledge changes frequently - Source attribution is required - Knowledge base is large or growing - Budget for training is limited - Multiple knowledge bases needed  Choose...
#  4. id=206    score=  1.7311 | Legal Research Assistant: Choose Hybrid. Fine-tune for legal reasoning patterns and citation style. Use RAG to retrieve relevant cases, statutes, and regulations.  Customer Service Bot (Narrow Domain): Could go either wa...
#  5. id=205    score=  1.0040 | Team Skills: RAG development aligns with traditional software engineering (databases, APIs, systems). Fine-tuning requires ML engineering expertise (training pipelines, GPU optimization, evaluation).  Case Studies and Re...
#
# Top-3 evidence chunk IDs: [189, 191, 207]
#
# --- Prompt-only answer ---
#  if you are unsure of your application's eligibility
#
# --- RAG-grounded answer ---
#  Cite evidence with [Chunk 1], [Chunk 2], etc.
#
# ==========================================================================================
# Q3 (ambiguous): How do I improve my RAG system?
#
# === BM25 Keyword (Top 5) ===
#  1. id=36     score=  9.2335 | Google IPO: Type in 'confusing,' 'secrecy' I've submitted my bid to buy shares of Google Inc. in the computer search company's giant auction-style initial public offering. That could turn out to be the good news or the b...
#  2. id=174    score=  5.9686 | Graph RAG Pattern  Graph RAG enhances retrieval by building a knowledge graph from the document corpus:  Named entities are extracted from documents and connected based on co-occurrence and relationships mentioned in tex...
#  3. id=160    score=  5.3252 | RAG Architectures and Design Patterns for Production Systems  Overview of RAG System Architecture  A production RAG system consists of several interconnected components working together to transform user queries into gro...
#  4. id=50     score=  4.8001 | Making Your Insurer Pay If Hurricane Charley blows your house down, how can you make your insurance company pay?
#  5. id=178    score=  4.7053 | The History and Evolution of Retrieval-Augmented Generation (RAG)  Introduction to RAG Origins  Retrieval-Augmented Generation, commonly known as RAG, represents a paradigm shift in how we build intelligent question-answ...
#
# === Vector (FAISS) (Top 5) ===
#  1. id=139    score=  0.5112 | Production RAG Deployment: Best Practices and Operational Considerations  From Prototype to Production  Building a RAG proof-of-concept is relatively straightforward with modern frameworks. However, deploying a reliable,...
#  2. id=208    score=  0.4722 | Conclusion  The RAG vs fine-tuning decision is not binary. Understanding the strengths and limitations of each approach enables practitioners to design systems that leverage both as appropriate. As the field evolves, we ...
#  3. id=203    score=  0.4661 | RAG-Aware Fine-Tuning: Fine-tune the model specifically for RAG scenarios, training it to effectively use retrieved context and know when retrieval is insufficient.  Routing Between Approaches: Use a classifier to route ...
#  4. id=196    score=  0.4610 | Task-Specific Optimization: For narrow tasks (classification, extraction, specific QA formats), fine-tuning can achieve superior performance compared to prompting general models.  Knowledge Freshness and Updates  RAG Adv...
#  5. id=177    score=  0.4485 | These optimizations can reduce perceived latency from several seconds to near-instantaneous responses.  Conclusion  Choosing the right RAG architecture depends on your use case, scale, and quality requirements. Simple pi...
#
# === Hybrid (alpha=0.2) (Top 5) ===
#  1. id=139    score=  0.8194 | Production RAG Deployment: Best Practices and Operational Considerations  From Prototype to Production  Building a RAG proof-of-concept is relatively straightforward with modern frameworks. However, deploying a reliable,...
#  2. id=208    score=  0.5663 | Conclusion  The RAG vs fine-tuning decision is not binary. Understanding the strengths and limitations of each approach enables practitioners to design systems that leverage both as appropriate. As the field evolves, we ...
#  3. id=203    score=  0.5302 | RAG-Aware Fine-Tuning: Fine-tune the model specifically for RAG scenarios, training it to effectively use retrieved context and know when retrieval is insufficient.  Routing Between Approaches: Use a classifier to route ...
#  4. id=196    score=  0.4994 | Task-Specific Optimization: For narrow tasks (classification, extraction, specific QA formats), fine-tuning can achieve superior performance compared to prompting general models.  Knowledge Freshness and Updates  RAG Adv...
#  5. id=177    score=  0.4358 | These optimizations can reduce perceived latency from several seconds to near-instantaneous responses.  Conclusion  Choosing the right RAG architecture depends on your use case, scale, and quality requirements. Simple pi...
#
# === Hybrid (alpha=0.5) (Top 5) ===
#  1. id=139    score=  0.5486 | Production RAG Deployment: Best Practices and Operational Considerations  From Prototype to Production  Building a RAG proof-of-concept is relatively straightforward with modern frameworks. However, deploying a reliable,...
#  2. id=36     score=  0.5000 | Google IPO: Type in 'confusing,' 'secrecy' I've submitted my bid to buy shares of Google Inc. in the computer search company's giant auction-style initial public offering. That could turn out to be the good news or the b...
#  3. id=208    score=  0.3539 | Conclusion  The RAG vs fine-tuning decision is not binary. Understanding the strengths and limitations of each approach enables practitioners to design systems that leverage both as appropriate. As the field evolves, we ...
#  4. id=203    score=  0.3314 | RAG-Aware Fine-Tuning: Fine-tune the model specifically for RAG scenarios, training it to effectively use retrieved context and know when retrieval is insufficient.  Routing Between Approaches: Use a classifier to route ...
#  5. id=196    score=  0.3121 | Task-Specific Optimization: For narrow tasks (classification, extraction, specific QA formats), fine-tuning can achieve superior performance compared to prompting general models.  Knowledge Freshness and Updates  RAG Adv...
#
# === Hybrid (alpha=0.8) (Top 5) ===
#  1. id=36     score=  0.8000 | Google IPO: Type in 'confusing,' 'secrecy' I've submitted my bid to buy shares of Google Inc. in the computer search company's giant auction-style initial public offering. That could turn out to be the good news or the b...
#  2. id=174    score=  0.2874 | Graph RAG Pattern  Graph RAG enhances retrieval by building a knowledge graph from the document corpus:  Named entities are extracted from documents and connected based on co-occurrence and relationships mentioned in tex...
#  3. id=139    score=  0.2777 | Production RAG Deployment: Best Practices and Operational Considerations  From Prototype to Production  Building a RAG proof-of-concept is relatively straightforward with modern frameworks. However, deploying a reliable,...
#  4. id=160    score=  0.1864 | RAG Architectures and Design Patterns for Production Systems  Overview of RAG System Architecture  A production RAG system consists of several interconnected components working together to transform user queries into gro...
#  5. id=177    score=  0.1504 | These optimizations can reduce perceived latency from several seconds to near-instantaneous responses.  Conclusion  Choosing the right RAG architecture depends on your use case, scale, and quality requirements. Simple pi...
#
# Selected hybrid alpha=0.2
#
# === Re-ranked (Top 5) ===
#  1. id=196    score=  2.8373 | Task-Specific Optimization: For narrow tasks (classification, extraction, specific QA formats), fine-tuning can achieve superior performance compared to prompting general models.  Knowledge Freshness and Updates  RAG Adv...
#  2. id=177    score=  0.5312 | These optimizations can reduce perceived latency from several seconds to near-instantaneous responses.  Conclusion  Choosing the right RAG architecture depends on your use case, scale, and quality requirements. Simple pi...
#  3. id=191    score=  0.0063 | Hybrid Approaches combine both: fine-tuning improves the model's understanding of domain terminology and reasoning patterns while RAG provides access to detailed, up-to-date factual information.  When to Choose RAG  RAG ...
#  4. id=174    score= -0.3334 | Graph RAG Pattern  Graph RAG enhances retrieval by building a knowledge graph from the document corpus:  Named entities are extracted from documents and connected based on co-occurrence and relationships mentioned in tex...
#  5. id=187    score= -1.7671 | Research continues on several fronts: self-reflective RAG systems that can evaluate their own retrieval quality, multi-modal RAG incorporating images and other media, and agentic RAG that can decompose complex questions ...
#
# Top-3 evidence chunk IDs: [196, 177, 191]
#
# --- Prompt-only answer ---
#  Use a syringe or a syringe swivel
#
# --- RAG-grounded answer ---
#  Cite evidence with [Chunk 1], [Chunk 2], etc.
# [{'query': 'Q1: What are the main types of hallucination in RAG systems and what causes them?',
#   'best_alpha': 0.8,
#   'top3_chunk_ids': [121, 120, 138],
#   'prompt_only': 'drowsiness and hallucinations',
#   'rag': 'Cite evidence with [Chunk 1], [Chunk 2], etc.'}]

# %% [markdown]
# ### ✍️ Cell Description (Student)
# Explain how you compared keyword/vector/hybrid retrieval, how you selected α, and how reranking affected the evidence.
#
# I think the hybrid approach is best because it gives the correct answer the highest relavance score and that score has the most distance from the next option so to me it is more confident.

# %% [markdown]
# ## 7) Metrics (Precision@5 / Recall@10) + Manual Relevance Labels  ✅ **IMPORTANT: Add Cell Description after running**

# %%
def precision_at_k(retrieved: List[int], relevant: Set[int], k: int = 5) -> float:
    top = retrieved[:k]
    if not top:
        return 0.0
    return sum(1 for i in top if i in relevant) / len(top)

def recall_at_k(retrieved: List[int], relevant: Set[int], k: int = 10) -> float:
    if not relevant:
        return 0.0
    return len(set(retrieved[:k]) & relevant) / len(relevant)

# ✅ REQUIRED: Label a small set of relevant chunk IDs for each query (after inspecting retrieval results).
relevance_labels = {
    "Q1: What are the main types of hallucination in RAG systems and what causes them?": {121},
    "Q2: When should I choose RAG over fine-tuning for my LLM application?": {189},
    "Q3 (ambiguous): How do I improve my RAG system?": {196},
}
relevance_labels

#
# Out:
# {'Q1: What are the main types of hallucination in RAG systems and what causes them?': {121},
#  'Q2: When should I choose RAG over fine-tuning for my LLM application?': {189},
#  'Q3 (ambiguous): How do I improve my RAG system?': {196}}

# %% [markdown]
# ### ✍️ Cell Description (Student)
# Explain what Precision@K and Recall@K mean in the context of RAG retrieval, and how you labeled relevance.

# %%
def evaluate_query(q: str, relevant: Set[int], alpha: float):
    kw_ids = [i for i, _ in keyword_bm25(q, k=10)]
    vec_ids = [i for i, _ in vector_search(q, k=10)]
    hyb_ids = [i for i, _ in hybrid_search(q, alpha=alpha, top_k=10, keyword_mode="bm25")]
    return {
        "P@5_keyword": precision_at_k(kw_ids, relevant, k=5),
        "R@10_keyword": recall_at_k(kw_ids, relevant, k=10),
        "P@5_vector": precision_at_k(vec_ids, relevant, k=5),
        "R@10_vector": recall_at_k(vec_ids, relevant, k=10),
        "P@5_hybrid": precision_at_k(hyb_ids, relevant, k=5),
        "R@10_hybrid": recall_at_k(hyb_ids, relevant, k=10),
    }

metrics_rows = []
for row in results_summary:
    q = row["query"]
    alpha = row["best_alpha"]
    rel = relevance_labels.get(q, set())
    m = evaluate_query(q, rel, alpha)
    m.update({"query": q, "alpha_used": alpha, "num_relevant_labeled": len(rel)})
    metrics_rows.append(m)

metrics_df = pd.DataFrame(metrics_rows)
metrics_df
# Out:
# Failed to connect to the remote Jupyter Server 'https://8080-m-s-1zzg3mvst07tw-a.us-west4-2.prod.colab.dev/'. Verify the server is running and reachable.

# %% [markdown]
# ## 8) README Checklist (Deliverables)
#
# Create a section titled **Lab 2 — Advanced RAG Results** in your repo README and include:
# - Results table (Query × Method × Precision@5 / Recall@10)
# - Screenshots: chunking comparison, reranking before/after, prompt-only vs RAG answers
# - Reflection (3–5 sentences): one failure case, which layer failed, one concrete fix
#
# ### Required Reflection Labels
# - Chunking failure
# - Retrieval failure
# - Re-ranking failure
# - Generation failure

# %% [markdown]
# ## 9) Final Requirement Reminder (2% Individual)
# To earn full credit, you must demonstrate:
# - **Project-aligned data** (your domain corpus)
# - **Three domain queries** (including one ambiguous case)
# - **One system customization** (chunking choice, α policy, model choice, etc.)
# - **One real failure case + fix**
